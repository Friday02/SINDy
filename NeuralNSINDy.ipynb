# %% [markdown]
# # SINDy Technique using Deep Learning

# %%
import numpy as np   
from sklearn.linear_model import LinearRegression
import pandas as pd    
import matplotlib.pyplot as plt 
# %matplotlib inline 
import seaborn as sns
import keras
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV
from sklearn.neural_network import MLPRegressor 
from keras.models import Sequential
from keras.layers import Dense, Activation, Input, Dropout
from sklearn.model_selection import train_test_split # Sklearn package's randomized data splitting function
from numpy import asarray
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import PolynomialFeatures
from sklearn.metrics import mean_squared_error

# %%
# %tensorflow_version 2.x
import tensorflow
tensorflow.__version__
# Out:
# UsageError: Line magic function `%tensorflow_version` not found.

# %%
# Initialize the random number generator
import random
random.seed(0)

# Ignore the warnings
import warnings
warnings.filterwarnings("ignore")

# %%
cData = pd.read_csv(r"C:\Users\Navnit Ashok Nair\OneDrive\Desktop\SINDy\TBC_data_study_1.csv")
cData=cData.drop(['Unnamed: 0','std_rho','std_R','RelativeDessityError','RelativeTBCError','dT'],axis=1)

x=cData.drop(['NSheets'],axis=1)
Y=cData['NSheets']
from imblearn.over_sampling import SMOTE
sm = SMOTE(random_state = 2)
x1, Y1 = sm.fit_resample(x, Y.ravel())
x1['NSheets']=Y1

x=x1.drop(['Temperature'],axis=1)
Y=x1['Temperature']
x1, Y1 = sm.fit_resample(x, Y.ravel())
x1['Temperature']=Y1



X = x1.drop(['RelativeTBR'], axis=1)
y = x1[['RelativeTBR']]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=1)
 # created scaler
scaler = StandardScaler()
    # fit scaler on training dataset
scaler.fit(X_train)
    # transform training dataset
X_train = scaler.transform(X_train)
    # transform test dataset
X_test = scaler.transform(X_test)
poly = PolynomialFeatures(degree=3, interaction_only=True)
X_train = poly.fit_transform(X_train)
X_test = poly.fit_transform(X_test)

# %%
y_train
# Out:
#       RelativeTBR
# 2360     1.029948
# 1021     1.161645
# 636      0.551196
# 180      1.809379
# 2703     1.179539
# ...           ...
# 2763     1.146955
# 905      1.092630
# 1096     1.088421
# 235      1.700032
# 1061     0.984842
#
# [2552 rows x 1 columns]

# %% [markdown]
# ### Print shape of the data

# %%
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (2552, 93)
# (2552, 1)
# (638, 93)
# (638, 1)

# %%
import itertools
# Define the pipeline
pipeline = Pipeline([
    ('scaler', StandardScaler()),  # Preprocessing step: StandardScaler
    ('mlp', None)  # Model building step: Keras MLP model
])

# Define the range of values for the number of layers
layer_range = range(1,4)  # Change the range as per your preference

best_score = float('inf')
best_num_layers = None
best_neurons = None

for num_layers in layer_range:
    neuron_configs = list(itertools.product([8,16,32,64,128], repeat=num_layers))

    for neurons in neuron_configs:
        if all(neuron <= 128 for neuron in neurons):
            model = Sequential()
            model.add(Dense(neurons[0], activation='relu', input_shape=(X_train.shape[1],)))
            model.add(Dropout(0.01))  # Add dropout layer
            for neuron in neurons[1:]:
                model.add(Dense(neuron, activation='relu'))
                model.add(Dropout(0.01))  # Add dropout layer
            model.add(Dense(1,activation='linear'))
            model.compile(optimizer='adam', loss='mean_squared_error')  # Compile the model



            pipeline.set_params(mlp=model)

            # Perform cross-validation
            grid_search = GridSearchCV(pipeline, param_grid={}, cv=5, scoring='neg_mean_squared_error')
            grid_search.fit(X_train, y_train)

            # Get the best score for the current configuration
            if grid_search.best_score_ < best_score:
                best_score = grid_search.best_score_
                best_num_layers = num_layers
                best_neurons = neurons

# Fit the pipeline with the best configuration on the entire training set
model = Sequential()
model.add(Dense(best_neurons[0], activation='relu', input_shape=(X_train.shape[1],)))
model.add(Dropout(0.2))
for neuron in best_neurons[1:]:
    model.add(Dense(neuron, activation='relu'))
    model.add(Dropout(0.2))
model.add(Dense(1,activation='linear'))
model.compile(optimizer='adam', loss='mean_squared_error')  # Compile the model


pipeline.set_params(mlp=model)
pipeline.fit(X_train, y_train)

# Evaluate the best model on test data
y_pred = pipeline.predict(X_test)
mse = mean_squared_error(y_test, y_pred)

print("Best number of layers:", best_num_layers+1)
print("Best neuron configuration:", best_neurons)
print("Mean Squared Error:", mse)
# Out:
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers\dense
# ......vars
# .........0
# .........1
# ...layers\dense_1
# ......vars
# .........0
# .........1
# ...layers\dropout
# ......vars
# ...optimizer
# ......vars
# .........0
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# config.json                                    2023-06-15 20:22:34         1558
# metadata.json                                  2023-06-15 20:22:34           64
# variables.h5                                   2023-06-15 20:22:34        16280
# Keras model archive loading:
# File Name                                             Modified             Size
# config.json                                    2023-06-15 20:22:34         1558
# metadata.json                                  2023-06-15 20:22:34           64
# variables.h5                                   2023-06-15 20:22:34        16280
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ...layers\dense
# ......vars
# .........0
# .........1
# ...layers\dense_1
# ......vars
# .........0
# .........1
# ...layers\dropout
# ......vars
# ...optimizer
# ......vars
# .........0
# ...vars
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers\dense
# ......vars
# .........0
# .........1
# ...layers\dense_1
# ......vars
# .........0
# .........1
# ...layers\dropout
# ......vars
# ...optimizer
# ......vars
# .........0
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# config.json                                    2023-06-15 20:22:34         1558
# metadata.json                                  2023-06-15 20:22:34           64
# variables.h5                                   2023-06-15 20:22:34        16280
# Keras model archive loading:
# File Name                                             Modified             Size
# config.json                                    2023-06-15 20:22:34         1558
# metadata.json                                  2023-06-15 20:22:34           64
# variables.h5                                   2023-06-15 20:22:34        16280
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ...layers\dense
# ......vars
# .........0
# .........1
# ...layers\dense_1
# ......vars
# .........0
# .........1
# ...layers\dropout
# ......vars
# ...optimizer
# ......vars
# .........0
# ...vars
# 64/64 [==============================] - 1s 5ms/step - loss: 1.6137
# 16/16 [==============================] - 0s 3ms/step
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers\dense
# ......vars
# .........0
# .........1
# ...layers\dense_1
# ......vars
# .........0
# .........1
# ...layers\dropout
# ......vars
# ...optimizer
# ......vars
# .........0
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# config.json                                    2023-06-15 20:22:36         1558
# metadata.json                                  2023-06-15 20:22:36           64
# variables.h5                                   2023-06-15 20:22:36        16280
# Keras model archive loading:
# File Name                                             Modified             Size
# config.json                                    2023-06-15 20:22:36         1558
# metadata.json                                  2023-06-15 20:22:36           64
# variables.h5                                   2023-06-15 20:22:36        16280
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ...layers\dense
# ......vars
# .........0
# .........1
# ...layers\dense_1
# ......vars
# .........0
# .........1
# ...layers\dropout
# ......vars
# ...optimizer
# ......vars
# .........0
# ...vars
# 64/64 [==============================] - 1s 3ms/step - loss: 1.5971
# 16/16 [==============================] - 0s 2ms/step
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers\dense
# ......vars
# .........0
# .........1
# ...layers\dense_1
# ......vars
# .........0
# .........1
# ...layers\dropout
# ......vars
# ...optimizer
# ......vars
# .........0
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# config.json                                    2023-06-15 20:22:38         1558
# metadata.json                                  2023-06-15 20:22:38           64
# variables.h5                                   2023-06-15 20:22:38        16280
# Keras model archive loading:
# File Name                                             Modified             Size
# config.json                                    2023-06-15 20:22:38         1558
# metadata.json                                  2023-06-15 20:22:38           64
# variables.h5                                   2023-06-15 20:22:38        16280
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ...layers\dense
# ......vars
# .........0
# .........1
# ...layers\dense_1
# ......vars
# .........0
# .........1
# ...layers\dropout
# ......vars
# ...optimizer
# ......vars
# .........0
# ...vars
# 64/64 [==============================] - 1s 3ms/step - loss: 1.5269
# 16/16 [==============================] - 0s 2ms/step
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers\dense
# ......vars
# .........0
# .........1
# ...layers\dense_1
# ......vars
# .........0
# .........1
# ...layers\dropout
# ......vars
# ...optimizer
# ......vars
# .........0
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# config.json                                    2023-06-15 20:22:39         1558
# metadata.json                                  2023-06-15 20:22:39           64
# variables.h5                                   2023-06-15 20:22:39        16280
# Keras model archive loading:
# File Name                                             Modified             Size
# config.json                                    2023-06-15 20:22:38         1558
# metadata.json                                  2023-06-15 20:22:38           64
# variables.h5                                   2023-06-15 20:22:38        16280
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ...layers\dense
# ......vars
# .........0
# .........1
# ...layers\dense_1
# ......vars
# .........0
# .........1
# ...layers\dropout
# ......vars
# ...optimizer
# ......vars
# .........0
# ...vars
# 64/64 [==============================] - 1s 3ms/step - loss: 1.5655
# 16/16 [==============================] - 0s 6ms/step
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers\dense
# ......vars
# .........0
# .........1
# ...layers\dense_1
# ......vars
# .........0
# .........1
# ...layers\dropout
# ......vars
# ...optimizer
# ......vars
# .........0
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# config.json                                    2023-06-15 20:22:40         1558
# metadata.json                                  2023-06-15 20:22:40           64
# variables.h5                                   2023-06-15 20:22:40        16280
# Keras model archive loading:
# File Name                                             Modified             Size
# config.json                                    2023-06-15 20:22:40         1558
# metadata.json                                  2023-06-15 20:22:40           64
# variables.h5                                   2023-06-15 20:22:40        16280
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ...layers\dense
# ......vars
# .........0
# .........1
# ...layers\dense_1
# ......vars
# .........0
# .........1
# ...layers\dropout
# ......vars
# ...optimizer
# ......vars
# .........0
# ...vars
# 64/64 [==============================] - 1s 4ms/step - loss: 1.5957
# 16/16 [==============================] - 0s 4ms/step
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers\dense
# ......vars
# .........0
# .........1
# ...layers\dense_1
# ......vars
# .........0
# .........1
# ...layers\dropout
# ......vars
# ...optimizer
# ......vars
# .........0
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# config.json                                    2023-06-15 20:22:42         1558
# metadata.json                                  2023-06-15 20:22:42           64
# variables.h5                                   2023-06-15 20:22:42        16280
# Keras model archive loading:
# File Name                                             Modified             Size
# config.json                                    2023-06-15 20:22:42         1558
# metadata.json                                  2023-06-15 20:22:42           64
# variables.h5                                   2023-06-15 20:22:42        16280
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ...layers\dense
# ......vars
# .........0
# .........1
# ...layers\dense_1
# ......vars
# .........0
# .........1
# ...layers\dropout
# ......vars
# ...optimizer
# ......vars
# .........0
# ...vars
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers\dense
# ......vars
# .........0
# .........1
# ...layers\dense_1
# ......vars
# .........0
# .........1
# ...layers\dropout
# ......vars
# ...optimizer
# ......vars
# .........0
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# config.json                                    2023-06-15 20:22:42         1558
# metadata.json                                  2023-06-15 20:22:42           64
# variables.h5                                   2023-06-15 20:22:42        16280
# Keras model archive loading:
# File Name                                             Modified             Size
# config.json                                    2023-06-15 20:22:42         1558
# metadata.json                                  2023-06-15 20:22:42           64
# variables.h5                                   2023-06-15 20:22:42        16280
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ...layers\dense
# ......vars
# .........0
# .........1
# ...layers\dense_1
# ......vars
# .........0
# .........1
# ...layers\dropout
# ......vars
# ...optimizer
# ......vars
# .........0
# ...vars
# 80/80 [==============================] - 1s 3ms/step - loss: 1.4613
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers\dense
# ......vars
# .........0
# .........1
# ...layers\dense_1
# ......vars
# .........0
# .........1
# ...layers\dropout
# ......vars
# ...optimizer
# ......vars
# .........0
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# config.json                                    2023-06-15 20:22:43         1559
# metadata.json                                  2023-06-15 20:22:43           64
# variables.h5                                   2023-06-15 20:22:43        19256
# Keras model archive loading:
# File Name                                             Modified             Size
# config.json                                    2023-06-15 20:22:42         1559
# metadata.json                                  2023-06-15 20:22:42           64
# variables.h5                                   2023-06-15 20:22:42        19256
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ...layers\dense
# ......vars
# .........0
# .........1
# ...layers\dense_1
# ......vars
# .........0
# .........1
# ...layers\dropout
# ......vars
# ...optimizer
# ......vars
# .........0
# ...vars
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers\dense
# ......vars
# .........0
# .........1
# ...layers\dense_1
# ......vars
# .........0
# .........1
# ...layers\dropout
# ......vars
# ...optimizer
# ......vars
# .........0
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# config.json                                    2023-06-15 20:22:44         1559
# metadata.json                                  2023-06-15 20:22:44           64
# variables.h5                                   2023-06-15 20:22:44        19256
# Keras model archive loading:
# File Name                                             Modified             Size
# config.json                                    2023-06-15 20:22:44         1559
# metadata.json                                  2023-06-15 20:22:44           64
# variables.h5                                   2023-06-15 20:22:44        19256
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ...layers\dense
# ......vars
# .........0
# .........1
# ...layers\dense_1
# ......vars
# .........0
# .........1
# ...layers\dropout
# ......vars
# ...optimizer
# ......vars
# .........0
# ...vars
# 64/64 [==============================] - 1s 3ms/step - loss: 1.4140
# 16/16 [==============================] - 0s 2ms/step
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers\dense
# ......vars
# .........0
# .........1
# ...layers\dense_1
# ......vars
# .........0
# .........1
# ...layers\dropout
# ......vars
# ...optimizer
# ......vars
# .........0
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# config.json                                    2023-06-15 20:22:45         1559
# metadata.json                                  2023-06-15 20:22:45           64
# variables.h5                                   2023-06-15 20:22:45        19256
# Keras model archive loading:
# File Name                                             Modified             Size
# config.json                                    2023-06-15 20:22:44         1559
# metadata.json                                  2023-06-15 20:22:44           64
# variables.h5                                   2023-06-15 20:22:44        19256
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ...layers\dense
# ......vars
# .........0
# .........1
# ...layers\dense_1
# ......vars
# .........0
# .........1
# ...layers\dropout
# ......vars
# ...optimizer
# ......vars
# .........0
# ...vars
# 64/64 [==============================] - 1s 3ms/step - loss: 1.5224
# 16/16 [==============================] - 0s 2ms/step
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers\dense
# ......vars
# .........0
# .........1
# ...layers\dense_1
# ......vars
# .........0
# .........1
# ...layers\dropout
# ......vars
# ...optimizer
# ......vars
# .........0
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# config.json                                    2023-06-15 20:22:46         1559
# metadata.json                                  2023-06-15 20:22:46           64
# variables.h5                                   2023-06-15 20:22:46        19256
# Keras model archive loading:
# File Name                                             Modified             Size
# config.json                                    2023-06-15 20:22:46         1559
# metadata.json                                  2023-06-15 20:22:46           64
# variables.h5                                   2023-06-15 20:22:46        19256
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ...layers\dense
# ......vars
# .........0
# .........1
# ...layers\dense_1
# ......vars
# .........0
# .........1
# ...layers\dropout
# ......vars
# ...optimizer
# ......vars
# .........0
# ...vars
# 64/64 [==============================] - 1s 4ms/step - loss: 1.7876
# 16/16 [==============================] - 0s 2ms/step
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers\dense
# ......vars
# .........0
# .........1
# ...layers\dense_1
# ......vars
# .........0
# .........1
# ...layers\dropout
# ......vars
# ...optimizer
# ......vars
# .........0
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# config.json                                    2023-06-15 20:22:48         1559
# metadata.json                                  2023-06-15 20:22:48           64
# variables.h5                                   2023-06-15 20:22:48        19256
# Keras model archive loading:
# File Name                                             Modified             Size
# config.json                                    2023-06-15 20:22:48         1559
# metadata.json                                  2023-06-15 20:22:48           64
# variables.h5                                   2023-06-15 20:22:48        19256
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ...layers\dense
# ......vars
# .........0
# .........1
# ...layers\dense_1
# ......vars
# .........0
# .........1
# ...layers\dropout
# ......vars
# ...optimizer
# ......vars
# .........0
# ...vars
# 64/64 [==============================] - 1s 2ms/step - loss: 1.9476
# 16/16 [==============================] - 0s 2ms/step
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers\dense
# ......vars
# .........0
# .........1
# ...layers\dense_1
# ......vars
# .........0
# .........1
# ...layers\dropout
# ......vars
# ...optimizer
# ......vars
# .........0
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# config.json                                    2023-06-15 20:22:49         1559
# metadata.json                                  2023-06-15 20:22:49           64
# variables.h5                                   2023-06-15 20:22:49        19256
# Keras model archive loading:
# File Name                                             Modified             Size
# config.json                                    2023-06-15 20:22:48         1559
# metadata.json                                  2023-06-15 20:22:48           64
# variables.h5                                   2023-06-15 20:22:48        19256
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ...layers\dense
# ......vars
# .........0
# .........1
# ...layers\dense_1
# ......vars
# .........0
# .........1
# ...layers\dropout
# ......vars
# ...optimizer
# ......vars
# .........0
# ...vars
# 64/64 [==============================] - 1s 2ms/step - loss: 1.7452
# 16/16 [==============================] - 0s 2ms/step
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers\dense
# ......vars
# .........0
# .........1
# ...layers\dense_1
# ......vars
# .........0
# .........1
# ...layers\dropout
# ......vars
# ...optimizer
# ......vars
# .........0
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# config.json                                    2023-06-15 20:22:50         1559
# metadata.json                                  2023-06-15 20:22:50           64
# variables.h5                                   2023-06-15 20:22:50        19256
# Keras model archive loading:
# File Name                                             Modified             Size
# config.json                                    2023-06-15 20:22:50         1559
# metadata.json                                  2023-06-15 20:22:50           64
# variables.h5                                   2023-06-15 20:22:50        19256
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ...layers\dense
# ......vars
# .........0
# .........1
# ...layers\dense_1
# ......vars
# .........0
# .........1
# ...layers\dropout
# ......vars
# ...optimizer
# ......vars
# .........0
# ...vars
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers\dense
# ......vars
# .........0
# .........1
# ...layers\dense_1
# ......vars
# .........0
# .........1
# ...layers\dropout
# ......vars
# ...optimizer
# ......vars
# .........0
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# config.json                                    2023-06-15 20:22:50         1559
# metadata.json                                  2023-06-15 20:22:50           64
# variables.h5                                   2023-06-15 20:22:50        19256
# Keras model archive loading:
# File Name                                             Modified             Size
# config.json                                    2023-06-15 20:22:50         1559
# metadata.json                                  2023-06-15 20:22:50           64
# variables.h5                                   2023-06-15 20:22:50        19256
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ...layers\dense
# ......vars
# .........0
# .........1
# ...layers\dense_1
# ......vars
# .........0
# .........1
# ...layers\dropout
# ......vars
# ...optimizer
# ......vars
# .........0
# ...vars
# 80/80 [==============================] - 1s 2ms/step - loss: 1.3929
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers\dense
# ......vars
# .........0
# .........1
# ...layers\dense_1
# ......vars
# .........0
# .........1
# ...layers\dropout
# ......vars
# ...optimizer
# ......vars
# .........0
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# config.json                                    2023-06-15 20:22:51         1559
# metadata.json                                  2023-06-15 20:22:51           64
# variables.h5                                   2023-06-15 20:22:51        25208
# Keras model archive loading:
# File Name                                             Modified             Size
# config.json                                    2023-06-15 20:22:50         1559
# metadata.json                                  2023-06-15 20:22:50           64
# variables.h5                                   2023-06-15 20:22:50        25208
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ...layers\dense
# ......vars
# .........0
# .........1
# ...layers\dense_1
# ......vars
# .........0
# .........1
# ...layers\dropout
# ......vars
# ...optimizer
# ......vars
# .........0
# ...vars
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers\dense
# ......vars
# .........0
# .........1
# ...layers\dense_1
# ......vars
# .........0
# .........1
# ...layers\dropout
# ......vars
# ...optimizer
# ......vars
# .........0
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# config.json                                    2023-06-15 20:22:52         1559
# metadata.json                                  2023-06-15 20:22:51           64
# variables.h5                                   2023-06-15 20:22:52        25208
# Keras model archive loading:
# File Name                                             Modified             Size
# config.json                                    2023-06-15 20:22:52         1559
# metadata.json                                  2023-06-15 20:22:50           64
# variables.h5                                   2023-06-15 20:22:52        25208
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ...layers\dense
# ......vars
# .........0
# .........1
# ...layers\dense_1
# ......vars
# .........0
# .........1
# ...layers\dropout
# ......vars
# ...optimizer
# ......vars
# .........0
# ...vars
# 64/64 [==============================] - 1s 2ms/step - loss: 0.6739
# 16/16 [==============================] - 0s 1ms/step
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers\dense
# ......vars
# .........0
# .........1
# ...layers\dense_1
# ......vars
# .........0
# .........1
# ...layers\dropout
# ......vars
# ...optimizer
# ......vars
# .........0
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# config.json                                    2023-06-15 20:22:53         1559
# metadata.json                                  2023-06-15 20:22:53           64
# variables.h5                                   2023-06-15 20:22:53        25208
# Keras model archive loading:
# File Name                                             Modified             Size
# config.json                                    2023-06-15 20:22:52         1559
# metadata.json                                  2023-06-15 20:22:52           64
# variables.h5                                   2023-06-15 20:22:52        25208
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ...layers\dense
# ......vars
# .........0
# .........1
# ...layers\dense_1
# ......vars
# .........0
# .........1
# ...layers\dropout
# ......vars
# ...optimizer
# ......vars
# .........0
# ...vars
# 64/64 [==============================] - 1s 2ms/step - loss: 0.4965
# 16/16 [==============================] - 0s 1ms/step
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers\dense
# ......vars
# .........0
# .........1
# ...layers\dense_1
# ......vars
# .........0
# .........1
# ...layers\dropout
# ......vars
# ...optimizer
# ......vars
# .........0
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# config.json                                    2023-06-15 20:22:54         1559
# metadata.json                                  2023-06-15 20:22:54           64
# variables.h5                                   2023-06-15 20:22:54        25208
# Keras model archive loading:
# File Name                                             Modified             Size
# config.json                                    2023-06-15 20:22:54         1559
# metadata.json                                  2023-06-15 20:22:54           64
# variables.h5                                   2023-06-15 20:22:54        25208
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ...layers\dense
# ......vars
# .........0
# .........1
# ...layers\dense_1
# ......vars
# .........0
# .........1
# ...layers\dropout
# ......vars
# ...optimizer
# ......vars
# .........0
# ...vars
# 64/64 [==============================] - 1s 3ms/step - loss: 0.6704
# 16/16 [==============================] - 0s 1ms/step
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers\dense
# ......vars
# .........0
# .........1
# ...layers\dense_1
# ......vars
# .........0
# .........1
# ...layers\dropout
# ......vars
# ...optimizer
# ......vars
# .........0
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# config.json                                    2023-06-15 20:22:55         1559
# metadata.json                                  2023-06-15 20:22:55           64
# variables.h5                                   2023-06-15 20:22:55        25208
# Keras model archive loading:
# File Name                                             Modified             Size
# config.json                                    2023-06-15 20:22:54         1559
# metadata.json                                  2023-06-15 20:22:54           64
# variables.h5                                   2023-06-15 20:22:54        25208
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ...layers\dense
# ......vars
# .........0
# .........1
# ...layers\dense_1
# ......vars
# .........0
# .........1
# ...layers\dropout
# ......vars
# ...optimizer
# ......vars
# .........0
# ...vars
# 64/64 [==============================] - 1s 2ms/step - loss: 0.5707
# 16/16 [==============================] - 0s 2ms/step
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers\dense
# ......vars
# .........0
# .........1
# ...layers\dense_1
# ......vars
# .........0
# .........1
# ...layers\dropout
# ......vars
# ...optimizer
# ......vars
# .........0
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# config.json                                    2023-06-15 20:22:56         1559
# metadata.json                                  2023-06-15 20:22:56           64
# variables.h5                                   2023-06-15 20:22:56        25208
# Keras model archive loading:
# File Name                                             Modified             Size
# config.json                                    2023-06-15 20:22:56         1559
# metadata.json                                  2023-06-15 20:22:56           64
# variables.h5                                   2023-06-15 20:22:56        25208
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ...layers\dense
# ......vars
# .........0
# .........1
# ...layers\dense_1
# ......vars
# .........0
# .........1
# ...layers\dropout
# ......vars
# ...optimizer
# ......vars
# .........0
# ...vars
# 64/64 [==============================] - 1s 3ms/step - loss: 0.5490
# 16/16 [==============================] - 0s 1ms/step
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers\dense
# ......vars
# .........0
# .........1
# ...layers\dense_1
# ......vars
# .........0
# .........1
# ...layers\dropout
# ......vars
# ...optimizer
# ......vars
# .........0
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# config.json                                    2023-06-15 20:22:57         1559
# metadata.json                                  2023-06-15 20:22:57           64
# variables.h5                                   2023-06-15 20:22:57        25208
# Keras model archive loading:
# File Name                                             Modified             Size
# config.json                                    2023-06-15 20:22:56         1559
# metadata.json                                  2023-06-15 20:22:56           64
# variables.h5                                   2023-06-15 20:22:56        25208
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ...layers\dense
# ......vars
# .........0
# .........1
# ...layers\dense_1
# ......vars
# .........0
# .........1
# ...layers\dropout
# ......vars
# ...optimizer
# ......vars
# .........0
# ...vars
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers\dense
# ......vars
# .........0
# .........1
# ...layers\dense_1
# ......vars
# .........0
# .........1
# ...layers\dropout
# ......vars
# ...optimizer
# ......vars
# .........0
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# config.json                                    2023-06-15 20:22:57         1559
# metadata.json                                  2023-06-15 20:22:57           64
# variables.h5                                   2023-06-15 20:22:57        25208
# Keras model archive loading:
# File Name                                             Modified             Size
# config.json                                    2023-06-15 20:22:56         1559
# metadata.json                                  2023-06-15 20:22:56           64
# variables.h5                                   2023-06-15 20:22:56        25208
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ...layers\dense
# ......vars
# .........0
# .........1
# ...layers\dense_1
# ......vars
# .........0
# .........1
# ...layers\dropout
# ......vars
# ...optimizer
# ......vars
# .........0
# ...vars
# 80/80 [==============================] - 1s 2ms/step - loss: 0.5583
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers\dense
# ......vars
# .........0
# .........1
# ...layers\dense_1
# ......vars
# .........0
# .........1
# ...layers\dropout
# ......vars
# ...optimizer
# ......vars
# .........0
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# config.json                                    2023-06-15 20:22:58         1559
# metadata.json                                  2023-06-15 20:22:58           64
# variables.h5                                   2023-06-15 20:22:58        37112
# Keras model archive loading:
# File Name                                             Modified             Size
# config.json                                    2023-06-15 20:22:58         1559
# metadata.json                                  2023-06-15 20:22:58           64
# variables.h5                                   2023-06-15 20:22:58        37112
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ...layers\dense
# ......vars
# .........0
# .........1
# ...layers\dense_1
# ......vars
# .........0
# .........1
# ...layers\dropout
# ......vars
# ...optimizer
# ......vars
# .........0
# ...vars
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers\dense
# ......vars
# .........0
# .........1
# ...layers\dense_1
# ......vars
# .........0
# .........1
# ...layers\dropout
# ......vars
# ...optimizer
# ......vars
# .........0
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# config.json                                    2023-06-15 20:22:58         1559
# metadata.json                                  2023-06-15 20:22:58           64
# variables.h5                                   2023-06-15 20:22:58        37112
# Keras model archive loading:
# File Name                                             Modified             Size
# config.json                                    2023-06-15 20:22:58         1559
# metadata.json                                  2023-06-15 20:22:58           64
# variables.h5                                   2023-06-15 20:22:58        37112
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ...layers\dense
# ......vars
# .........0
# .........1
# ...layers\dense_1
# ......vars
# .........0
# .........1
# ...layers\dropout
# ......vars
# ...optimizer
# ......vars
# .........0
# ...vars
# 64/64 [==============================] - 1s 5ms/step - loss: 0.6483
# 16/16 [==============================] - 0s 3ms/step
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers\dense
# ......vars
# .........0
# .........1
# ...layers\dense_1
# ......vars
# .........0
# .........1
# ...layers\dropout
# ......vars
# ...optimizer
# ......vars
# .........0
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# config.json                                    2023-06-15 20:23:00         1559
# metadata.json                                  2023-06-15 20:23:00           64
# variables.h5                                   2023-06-15 20:23:00        37112
# Keras model archive loading:
# File Name                                             Modified             Size
# config.json                                    2023-06-15 20:23:00         1559
# metadata.json                                  2023-06-15 20:23:00           64
# variables.h5                                   2023-06-15 20:23:00        37112
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ...layers\dense
# ......vars
# .........0
# .........1
# ...layers\dense_1
# ......vars
# .........0
# .........1
# ...layers\dropout
# ......vars
# ...optimizer
# ......vars
# .........0
# ...vars
# 64/64 [==============================] - 6s 5ms/step - loss: 0.6388
# 16/16 [==============================] - 0s 3ms/step
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers\dense
# ......vars
# .........0
# .........1
# ...layers\dense_1
# ......vars
# .........0
# .........1
# ...layers\dropout
# ......vars
# ...optimizer
# ......vars
# .........0
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# config.json                                    2023-06-15 20:23:06         1559
# metadata.json                                  2023-06-15 20:23:06           64
# variables.h5                                   2023-06-15 20:23:06        37112
# Keras model archive loading:
# File Name                                             Modified             Size
# config.json                                    2023-06-15 20:23:06         1559
# metadata.json                                  2023-06-15 20:23:06           64
# variables.h5                                   2023-06-15 20:23:06        37112
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ...layers\dense
# ......vars
# .........0
# .........1
# ...layers\dense_1
# ......vars
# .........0
# .........1
# ...layers\dropout
# ......vars
# ...optimizer
# ......vars
# .........0
# ...vars
# 64/64 [==============================] - 1s 5ms/step - loss: 0.5649
# 16/16 [==============================] - 0s 3ms/step
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers\dense
# ......vars
# .........0
# .........1
# ...layers\dense_1
# ......vars
# .........0
# .........1
# ...layers\dropout
# ......vars
# ...optimizer
# ......vars
# .........0
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# config.json                                    2023-06-15 20:23:08         1559
# metadata.json                                  2023-06-15 20:23:08           64
# variables.h5                                   2023-06-15 20:23:08        37112
# Keras model archive loading:
# File Name                                             Modified             Size
# config.json                                    2023-06-15 20:23:08         1559
# metadata.json                                  2023-06-15 20:23:08           64
# variables.h5                                   2023-06-15 20:23:08        37112
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ...layers\dense
# ......vars
# .........0
# .........1
# ...layers\dense_1
# ......vars
# .........0
# .........1
# ...layers\dropout
# ......vars
# ...optimizer
# ......vars
# .........0
# ...vars
# 64/64 [==============================] - 1s 4ms/step - loss: 0.6859
# 16/16 [==============================] - 0s 2ms/step
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers\dense
# ......vars
# .........0
# .........1
# ...layers\dense_1
# ......vars
# .........0
# .........1
# ...layers\dropout
# ......vars
# ...optimizer
# ......vars
# .........0
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# config.json                                    2023-06-15 20:23:09         1559
# metadata.json                                  2023-06-15 20:23:09           64
# variables.h5                                   2023-06-15 20:23:09        37112
# Keras model archive loading:
# File Name                                             Modified             Size
# config.json                                    2023-06-15 20:23:08         1559
# metadata.json                                  2023-06-15 20:23:08           64
# variables.h5                                   2023-06-15 20:23:08        37112
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ...layers\dense
# ......vars
# .........0
# .........1
# ...layers\dense_1
# ......vars
# .........0
# .........1
# ...layers\dropout
# ......vars
# ...optimizer
# ......vars
# .........0
# ...vars
# 64/64 [==============================] - 1s 5ms/step - loss: 0.6521
# 16/16 [==============================] - 0s 3ms/step
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers\dense
# ......vars
# .........0
# .........1
# ...layers\dense_1
# ......vars
# .........0
# .........1
# ...layers\dropout
# ......vars
# ...optimizer
# ......vars
# .........0
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# config.json                                    2023-06-15 20:23:11         1559
# metadata.json                                  2023-06-15 20:23:11           64
# variables.h5                                   2023-06-15 20:23:11        37112
# Keras model archive loading:
# File Name                                             Modified             Size
# config.json                                    2023-06-15 20:23:10         1559
# metadata.json                                  2023-06-15 20:23:10           64
# variables.h5                                   2023-06-15 20:23:10        37112
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ...layers\dense
# ......vars
# .........0
# .........1
# ...layers\dense_1
# ......vars
# .........0
# .........1
# ...layers\dropout
# ......vars
# ...optimizer
# ......vars
# .........0
# ...vars
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers\dense
# ......vars
# .........0
# .........1
# ...layers\dense_1
# ......vars
# .........0
# .........1
# ...layers\dropout
# ......vars
# ...optimizer
# ......vars
# .........0
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# config.json                                    2023-06-15 20:23:11         1559
# metadata.json                                  2023-06-15 20:23:11           64
# variables.h5                                   2023-06-15 20:23:11        37112
# Keras model archive loading:
# File Name                                             Modified             Size
# config.json                                    2023-06-15 20:23:10         1559
# metadata.json                                  2023-06-15 20:23:10           64
# variables.h5                                   2023-06-15 20:23:10        37112
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ...layers\dense
# ......vars
# .........0
# .........1
# ...layers\dense_1
# ......vars
# .........0
# .........1
# ...layers\dropout
# ......vars
# ...optimizer
# ......vars
# .........0
# ...vars
# 80/80 [==============================] - 1s 4ms/step - loss: 0.5169
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers\dense
# ......vars
# .........0
# .........1
# ...layers\dense_1
# ......vars
# .........0
# .........1
# ...layers\dropout
# ......vars
# ...optimizer
# ......vars
# .........0
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# config.json                                    2023-06-15 20:23:12         1560
# metadata.json                                  2023-06-15 20:23:12           64
# variables.h5                                   2023-06-15 20:23:12        60920
# Keras model archive loading:
# File Name                                             Modified             Size
# config.json                                    2023-06-15 20:23:12         1560
# metadata.json                                  2023-06-15 20:23:12           64
# variables.h5                                   2023-06-15 20:23:12        60920
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ...layers\dense
# ......vars
# .........0
# .........1
# ...layers\dense_1
# ......vars
# .........0
# .........1
# ...layers\dropout
# ......vars
# ...optimizer
# ......vars
# .........0
# ...vars
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers\dense
# ......vars
# .........0
# .........1
# ...layers\dense_1
# ......vars
# .........0
# .........1
# ...layers\dropout
# ......vars
# ...optimizer
# ......vars
# .........0
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# config.json                                    2023-06-15 20:23:12         1560
# metadata.json                                  2023-06-15 20:23:12           64
# variables.h5                                   2023-06-15 20:23:12        60920
# Keras model archive loading:
# File Name                                             Modified             Size
# config.json                                    2023-06-15 20:23:12         1560
# metadata.json                                  2023-06-15 20:23:12           64
# variables.h5                                   2023-06-15 20:23:12        60920
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ...layers\dense
# ......vars
# .........0
# .........1
# ...layers\dense_1
# ......vars
# .........0
# .........1
# ...layers\dropout
# ......vars
# ...optimizer
# ......vars
# .........0
# ...vars
# 64/64 [==============================] - 1s 6ms/step - loss: 0.3855
# 16/16 [==============================] - 0s 3ms/step
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers\dense
# ......vars
# .........0
# .........1
# ...layers\dense_1
# ......vars
# .........0
# .........1
# ...layers\dropout
# ......vars
# ...optimizer
# ......vars
# .........0
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# config.json                                    2023-06-15 20:23:14         1560
# metadata.json                                  2023-06-15 20:23:14           64
# variables.h5                                   2023-06-15 20:23:14        60920
# Keras model archive loading:
# File Name                                             Modified             Size
# config.json                                    2023-06-15 20:23:14         1560
# metadata.json                                  2023-06-15 20:23:14           64
# variables.h5                                   2023-06-15 20:23:14        60920
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ...layers\dense
# ......vars
# .........0
# .........1
# ...layers\dense_1
# ......vars
# .........0
# .........1
# ...layers\dropout
# ......vars
# ...optimizer
# ......vars
# .........0
# ...vars
# 64/64 [==============================] - 1s 6ms/step - loss: 0.4450
# 16/16 [==============================] - 0s 3ms/step
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers\dense
# ......vars
# .........0
# .........1
# ...layers\dense_1
# ......vars
# .........0
# .........1
# ...layers\dropout
# ......vars
# ...optimizer
# ......vars
# .........0
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# config.json                                    2023-06-15 20:23:15         1560
# metadata.json                                  2023-06-15 20:23:15           64
# variables.h5                                   2023-06-15 20:23:16        60920
# Keras model archive loading:
# File Name                                             Modified             Size
# config.json                                    2023-06-15 20:23:14         1560
# metadata.json                                  2023-06-15 20:23:14           64
# variables.h5                                   2023-06-15 20:23:16        60920
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ...layers\dense
# ......vars
# .........0
# .........1
# ...layers\dense_1
# ......vars
# .........0
# .........1
# ...layers\dropout
# ......vars
# ...optimizer
# ......vars
# .........0
# ...vars
# 64/64 [==============================] - 1s 6ms/step - loss: 0.3287
# 16/16 [==============================] - 0s 2ms/step
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers\dense
# ......vars
# .........0
# .........1
# ...layers\dense_1
# ......vars
# .........0
# .........1
# ...layers\dropout
# ......vars
# ...optimizer
# ......vars
# .........0
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# config.json                                    2023-06-15 20:23:17         1560
# metadata.json                                  2023-06-15 20:23:17           64
# variables.h5                                   2023-06-15 20:23:17        60920
# Keras model archive loading:
# File Name                                             Modified             Size
# config.json                                    2023-06-15 20:23:16         1560
# metadata.json                                  2023-06-15 20:23:16           64
# variables.h5                                   2023-06-15 20:23:16        60920
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ...layers\dense
# ......vars
# .........0
# .........1
# ...layers\dense_1
# ......vars
# .........0
# .........1
# ...layers\dropout
# ......vars
# ...optimizer
# ......vars
# .........0
# ...vars
# 64/64 [==============================] - 1s 6ms/step - loss: 0.3505
# 16/16 [==============================] - 0s 3ms/step
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers\dense
# ......vars
# .........0
# .........1
# ...layers\dense_1
# ......vars
# .........0
# .........1
# ...layers\dropout
# ......vars
# ...optimizer
# ......vars
# .........0
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# config.json                                    2023-06-15 20:23:19         1560
# metadata.json                                  2023-06-15 20:23:19           64
# variables.h5                                   2023-06-15 20:23:19        60920
# Keras model archive loading:
# File Name                                             Modified             Size
# config.json                                    2023-06-15 20:23:18         1560
# metadata.json                                  2023-06-15 20:23:18           64
# variables.h5                                   2023-06-15 20:23:18        60920
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ...layers\dense
# ......vars
# .........0
# .........1
# ...layers\dense_1
# ......vars
# .........0
# .........1
# ...layers\dropout
# ......vars
# ...optimizer
# ......vars
# .........0
# ...vars
# 64/64 [==============================] - 1s 6ms/step - loss: 0.3886
# 16/16 [==============================] - 0s 3ms/step
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers\dense
# ......vars
# .........0
# .........1
# ...
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers\dense
# ......vars
# .........0
# .........1
# ...layers\dense_1
# ......vars
# .........0
# .........1
# ...layers\dense_2
# ......vars
# .........0
# .........1
# ...layers\dense_3
# ......vars
# .........0
# .........1
# ...layers\dropout
# ......vars
# ...layers\dropout_1
# ......vars
# ...layers\dropout_2
# ......vars
# ...optimizer
# ......vars
# .........0
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# config.json                                    2023-06-15 21:09:00         2717
# metadata.json                                  2023-06-15 21:09:00           64
# variables.h5                                   2023-06-15 21:09:00       168200
# Keras model archive loading:
# File Name                                             Modified             Size
# config.json                                    2023-06-15 21:09:00         2717
# metadata.json                                  2023-06-15 21:09:00           64
# variables.h5                                   2023-06-15 21:09:00       168200
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ...layers\dense
# ......vars
# .........0
# .........1
# ...layers\dense_1
# ......vars
# .........0
# .........1
# ...layers\dense_2
# ......vars
# .........0
# .........1
# ...layers\dense_3
# ......vars
# .........0
# .........1
# ...layers\dropout
# ......vars
# ...layers\dropout_1
# ......vars
# ...layers\dropout_2
# ......vars
# ...optimizer
# ......vars
# .........0
# ...vars
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers\dense
# ......vars
# .........0
# .........1
# ...layers\dense_1
# ......vars
# .........0
# .........1
# ...layers\dense_2
# ......vars
# .........0
# .........1
# ...layers\dense_3
# ......vars
# .........0
# .........1
# ...layers\dropout
# ......vars
# ...layers\dropout_1
# ......vars
# ...layers\dropout_2
# ......vars
# ...optimizer
# ......vars
# .........0
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# config.json                                    2023-06-15 21:09:01         2717
# metadata.json                                  2023-06-15 21:09:01           64
# variables.h5                                   2023-06-15 21:09:01       168200
# Keras model archive loading:
# File Name                                             Modified             Size
# config.json                                    2023-06-15 21:09:00         2717
# metadata.json                                  2023-06-15 21:09:00           64
# variables.h5                                   2023-06-15 21:09:00       168200
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ...layers\dense
# ......vars
# .........0
# .........1
# ...layers\dense_1
# ......vars
# .........0
# .........1
# ...layers\dense_2
# ......vars
# .........0
# .........1
# ...layers\dense_3
# ......vars
# .........0
# .........1
# ...layers\dropout
# ......vars
# ...layers\dropout_1
# ......vars
# ...layers\dropout_2
# ......vars
# ...optimizer
# ......vars
# .........0
# ...vars
# 80/80 [==============================] - 5s 28ms/step - loss: 0.2146
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers\dense
# ......vars
# .........0
# .........1
# ...layers\dense_1
# ......vars
# .........0
# .........1
# ...layers\dense_2
# ......vars
# .........0
# .........1
# ...layers\dense_3
# ......vars
# .........0
# .........1
# ...layers\dropout
# ......vars
# ...layers\dropout_1
# ......vars
# ...layers\dropout_2
# ......vars
# ...optimizer
# ......vars
# .........0
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# config.json                                    2023-06-15 21:09:06         2718
# metadata.json                                  2023-06-15 21:09:06           64
# variables.h5                                   2023-06-15 21:09:07       203016
# Keras model archive loading:
# File Name                                             Modified             Size
# config.json                                    2023-06-15 21:09:06         2718
# metadata.json                                  2023-06-15 21:09:06           64
# variables.h5                                   2023-06-15 21:09:06       203016
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ...layers\dense
# ......vars
# .........0
# .........1
# ...layers\dense_1
# ......vars
# .........0
# .........1
# ...layers\dense_2
# ......vars
# .........0
# .........1
# ...layers\dense_3
# ......vars
# .........0
# .........1
# ...layers\dropout
# ......vars
# ...layers\dropout_1
# ......vars
# ...layers\dropout_2
# ......vars
# ...optimizer
# ......vars
# .........0
# ...vars
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers\dense
# ......vars
# .........0
# .........1
# ...layers\dense_1
# ......vars
# .........0
# .........1
# ...layers\dense_2
# ......vars
# .........0
# .........1
# ...layers\dense_3
# ......vars
# .........0
# .........1
# ...layers\dropout
# ......vars
# ...layers\dropout_1
# ......vars
# ...layers\dropout_2
# ......vars
# ...optimizer
# ......vars
# .........0
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# config.json                                    2023-06-15 21:09:07         2718
# metadata.json                                  2023-06-15 21:09:07           64
# variables.h5                                   2023-06-15 21:09:07       203016
# Keras model archive loading:
# File Name                                             Modified             Size
# config.json                                    2023-06-15 21:09:06         2718
# metadata.json                                  2023-06-15 21:09:06           64
# variables.h5                                   2023-06-15 21:09:06       203016
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ...layers\dense
# ......vars
# .........0
# .........1
# ...layers\dense_1
# ......vars
# .........0
# .........1
# ...layers\dense_2
# ......vars
# .........0
# .........1
# ...layers\dense_3
# ......vars
# .........0
# .........1
# ...layers\dropout
# ......vars
# ...layers\dropout_1
# ......vars
# ...layers\dropout_2
# ......vars
# ...optimizer
# ......vars
# .........0
# ...vars
# 64/64 [==============================] - 4s 26ms/step - loss: 0.2116
# 16/16 [==============================] - 0s 7ms/step
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers\dense
# ......vars
# .........0
# .........1
# ...layers\dense_1
# ......vars
# .........0
# .........1
# ...layers\dense_2
# ......vars
# .........0
# .........1
# ...layers\dense_3
# ......vars
# .........0
# .........1
# ...layers\dropout
# ......vars
# ...layers\dropout_1
# ......vars
# ...layers\dropout_2
# ......vars
# ...optimizer
# ......vars
# .........0
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# config.json                                    2023-06-15 21:09:12         2718
# metadata.json                                  2023-06-15 21:09:12           64
# variables.h5                                   2023-06-15 21:09:12       203016
# Keras model archive loading:
# File Name                                             Modified             Size
# config.json                                    2023-06-15 21:09:12         2718
# metadata.json                                  2023-06-15 21:09:12           64
# variables.h5                                   2023-06-15 21:09:12       203016
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ...layers\dense
# ......vars
# .........0
# .........1
# ...layers\dense_1
# ......vars
# .........0
# .........1
# ...layers\dense_2
# ......vars
# .........0
# .........1
# ...layers\dense_3
# ......vars
# .........0
# .........1
# ...layers\dropout
# ......vars
# ...layers\dropout_1
# ......vars
# ...layers\dropout_2
# ......vars
# ...optimizer
# ......vars
# .........0
# ...vars
# 64/64 [==============================] - 4s 32ms/step - loss: 0.1908
# 16/16 [==============================] - 0s 7ms/step
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers\dense
# ......vars
# .........0
# .........1
# ...layers\dense_1
# ......vars
# .........0
# .........1
# ...layers\dense_2
# ......vars
# .........0
# .........1
# ...layers\dense_3
# ......vars
# .........0
# .........1
# ...layers\dropout
# ......vars
# ...layers\dropout_1
# ......vars
# ...layers\dropout_2
# ......vars
# ...optimizer
# ......vars
# .........0
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# config.json                                    2023-06-15 21:09:18         2718
# metadata.json                                  2023-06-15 21:09:18           64
# variables.h5                                   2023-06-15 21:09:18       203016
# Keras model archive loading:
# File Name                                             Modified             Size
# config.json                                    2023-06-15 21:09:18         2718
# metadata.json                                  2023-06-15 21:09:18           64
# variables.h5                                   2023-06-15 21:09:18       203016
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ...layers\dense
# ......vars
# .........0
# .........1
# ...layers\dense_1
# ......vars
# .........0
# .........1
# ...layers\dense_2
# ......vars
# .........0
# .........1
# ...layers\dense_3
# ......vars
# .........0
# .........1
# ...layers\dropout
# ......vars
# ...layers\dropout_1
# ......vars
# ...layers\dropout_2
# ......vars
# ...optimizer
# ......vars
# .........0
# ...vars
# 64/64 [==============================] - 4s 23ms/step - loss: 0.2106
# 16/16 [==============================] - 0s 7ms/step
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers\dense
# ......vars
# .........0
# .........1
# ...layers\dense_1
# ......vars
# .........0
# .........1
# ...layers\dense_2
# ......vars
# .........0
# .........1
# ...layers\dense_3
# ......vars
# .........0
# .........1
# ...layers\dropout
# ......vars
# ...layers\dropout_1
# ......vars
# ...layers\dropout_2
# ......vars
# ...optimizer
# ......vars
# .........0
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# config.json                                    2023-06-15 21:09:24         2718
# metadata.json                                  2023-06-15 21:09:24           64
# variables.h5                                   2023-06-15 21:09:24       203016
# Keras model archive loading:
# File Name                                             Modified             Size
# config.json                                    2023-06-15 21:09:24         2718
# metadata.json                                  2023-06-15 21:09:24           64
# variables.h5                                   2023-06-15 21:09:24       203016
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ...layers\dense
# ......vars
# .........0
# .........1
# ...layers\dense_1
# ......vars
# .........0
# .........1
# ...layers\dense_2
# ......vars
# .........0
# .........1
# ...layers\dense_3
# ......vars
# .........0
# .........1
# ...layers\dropout
# ......vars
# ...layers\dropout_1
# ......vars
# ...layers\dropout_2
# ......vars
# ...optimizer
# ......vars
# .........0
# ...vars
# 64/64 [==============================] - 4s 29ms/step - loss: 0.2457
# 16/16 [==============================] - 0s 8ms/step
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers\dense
# ......vars
# .........0
# .........1
# ...layers\dense_1
# ......vars
# .........0
# .........1
# ...layers\dense_2
# ......vars
# .........0
# .........1
# ...layers\dense_3
# ......vars
# .........0
# .........1
# ...layers\dropout
# ......vars
# ...layers\dropout_1
# ......vars
# ...layers\dropout_2
# ......vars
# ...optimizer
# ......vars
# .........0
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# config.json                                    2023-06-15 21:09:29         2718
# metadata.json                                  2023-06-15 21:09:29           64
# variables.h5                                   2023-06-15 21:09:30       203016
# Keras model archive loading:
# File Name                                             Modified             Size
# config.json                                    2023-06-15 21:09:28         2718
# metadata.json                                  2023-06-15 21:09:28           64
# variables.h5                                   2023-06-15 21:09:30       203016
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ...layers\dense
# ......vars
# .........0
# .........1
# ...layers\dense_1
# ......vars
# .........0
# .........1
# ...layers\dense_2
# ......vars
# .........0
# .........1
# ...layers\dense_3
# ......vars
# .........0
# .........1
# ...layers\dropout
# ......vars
# ...layers\dropout_1
# ......vars
# ...layers\dropout_2
# ......vars
# ...optimizer
# ......vars
# .........0
# ...vars
# 64/64 [==============================] - 4s 20ms/step - loss: 0.2039
# 16/16 [==============================] - 0s 5ms/step
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers\dense
# ......vars
# .........0
# .........1
# ...layers\dense_1
# ......vars
# .........0
# .........1
# ...layers\dense_2
# ......vars
# .........0
# .........1
# ...layers\dense_3
# ......vars
# .........0
# .........1
# ...layers\dropout
# ......vars
# ...layers\dropout_1
# ......vars
# ...layers\dropout_2
# ......vars
# ...optimizer
# ......vars
# .........0
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# config.json                                    2023-06-15 21:09:38         2718
# metadata.json                                  2023-06-15 21:09:38           64
# variables.h5                                   2023-06-15 21:09:38       203016
# Keras model archive loading:
# File Name                                             Modified             Size
# config.json                                    2023-06-15 21:09:38         2718
# metadata.json                                  2023-06-15 21:09:38           64
# variables.h5                                   2023-06-15 21:09:38       203016
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ...layers\dense
# ......vars
# .........0
# .........1
# ...layers\dense_1
# ......vars
# .........0
# .........1
# ...layers\dense_2
# ......vars
# .........0
# .........1
# ...layers\dense_3
# ......vars
# .........0
# .........1
# ...layers\dropout
# ......vars
# ...layers\dropout_1
# ......vars
# ...layers\dropout_2
# ......vars
# ...optimizer
# ......vars
# .........0
# ...vars
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers\dense
# ......vars
# .........0
# .........1
# ...layers\dense_1
# ......vars
# .........0
# .........1
# ...layers\dense_2
# ......vars
# .........0
# .........1
# ...layers\dense_3
# ......vars
# .........0
# .........1
# ...layers\dropout
# ......vars
# ...layers\dropout_1
# ......vars
# ...layers\dropout_2
# ......vars
# ...optimizer
# ......vars
# .........0
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# config.json                                    2023-06-15 21:09:39         2718
# metadata.json                                  2023-06-15 21:09:39           64
# variables.h5                                   2023-06-15 21:09:39       203016
# Keras model archive loading:
# File Name                                             Modified             Size
# config.json                                    2023-06-15 21:09:38         2718
# metadata.json                                  2023-06-15 21:09:38           64
# variables.h5                                   2023-06-15 21:09:38       203016
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ...layers\dense
# ......vars
# .........0
# .........1
# ...layers\dense_1
# ......vars
# .........0
# .........1
# ...layers\dense_2
# ......vars
# .........0
# .........1
# ...layers\dense_3
# ......vars
# .........0
# .........1
# ...layers\dropout
# ......vars
# ...layers\dropout_1
# ......vars
# ...layers\dropout_2
# ......vars
# ...optimizer
# ......vars
# .........0
# ...vars
# 80/80 [==============================] - 7s 36ms/step - loss: 0.1539
# 80/80 [==============================] - 3s 13ms/step - loss: 0.8261
# 20/20 [==============================] - 0s 6ms/step
# Best number of layers: 4
# Best neuron configuration: (8, 8, 8)
# Mean Squared Error: 0.5809327837840388

# %% [markdown]
# # Best Configeration from Max 5 layers of Hyperparameter Tuning

# %%
model1 = Sequential()
model1.add(Dense(32, activation='relu', input_shape=(X_train.shape[1],)))
model1.add(Dropout(0.01))
model1.add(Dense(16, activation='relu'))
model1.add(Dropout(0.01))
model1.add(Dense(8, activation='relu'))
model1.add(Dropout(0.01))
model1.add(Dense(1,activation='linear'))
model1.compile(optimizer='adam', loss='mean_squared_error')
model1.fit( x=X_train, y=y_train, batch_size=32, epochs=100, validation_split = 0.3)
model1.evaluate(X_test, y_test)
# Out:
# Epoch 1/100
# 56/56 [==============================] - 2s 10ms/step - loss: 0.3074 - val_loss: 0.1255
# Epoch 2/100
# 56/56 [==============================] - 0s 7ms/step - loss: 0.0707 - val_loss: 0.0653
# Epoch 3/100
# 56/56 [==============================] - 1s 10ms/step - loss: 0.0454 - val_loss: 0.0577
# Epoch 4/100
# 56/56 [==============================] - 1s 11ms/step - loss: 0.0256 - val_loss: 0.0475
# Epoch 5/100
# 56/56 [==============================] - 1s 12ms/step - loss: 0.0189 - val_loss: 0.0457
# Epoch 6/100
# 56/56 [==============================] - 1s 10ms/step - loss: 0.0194 - val_loss: 0.0415
# Epoch 7/100
# 56/56 [==============================] - 0s 6ms/step - loss: 0.0172 - val_loss: 0.0432
# Epoch 8/100
# 56/56 [==============================] - 0s 6ms/step - loss: 0.0328 - val_loss: 0.0312
# Epoch 9/100
# 56/56 [==============================] - 0s 5ms/step - loss: 0.0203 - val_loss: 0.0125
# Epoch 10/100
# 56/56 [==============================] - 0s 6ms/step - loss: 0.0136 - val_loss: 0.0114
# Epoch 11/100
# 56/56 [==============================] - 0s 5ms/step - loss: 0.0161 - val_loss: 0.0090
# Epoch 12/100
# 56/56 [==============================] - 0s 5ms/step - loss: 0.0156 - val_loss: 0.0061
# Epoch 13/100
# 56/56 [==============================] - 0s 5ms/step - loss: 0.0151 - val_loss: 0.0080
# Epoch 14/100
# 56/56 [==============================] - 0s 5ms/step - loss: 0.0141 - val_loss: 0.0066
# Epoch 15/100
# 56/56 [==============================] - 0s 5ms/step - loss: 0.0118 - val_loss: 0.0062
# Epoch 16/100
# 56/56 [==============================] - 0s 5ms/step - loss: 0.0120 - val_loss: 0.0059
# Epoch 17/100
# 56/56 [==============================] - 0s 6ms/step - loss: 0.0103 - val_loss: 0.0056
# Epoch 18/100
# 56/56 [==============================] - 0s 5ms/step - loss: 0.0095 - val_loss: 0.0055
# Epoch 19/100
# 56/56 [==============================] - 0s 5ms/step - loss: 0.0099 - val_loss: 0.0058
# Epoch 20/100
# 56/56 [==============================] - 0s 5ms/step - loss: 0.0093 - val_loss: 0.0060
# Epoch 21/100
# 56/56 [==============================] - 0s 5ms/step - loss: 0.0109 - val_loss: 0.0060
# Epoch 22/100
# 56/56 [==============================] - 0s 5ms/step - loss: 0.0102 - val_loss: 0.0064
# Epoch 23/100
# 56/56 [==============================] - 0s 5ms/step - loss: 0.0085 - val_loss: 0.0054
# Epoch 24/100
# 56/56 [==============================] - 0s 5ms/step - loss: 0.0315 - val_loss: 0.0118
# Epoch 25/100
# 56/56 [==============================] - 0s 5ms/step - loss: 0.0111 - val_loss: 0.0387
# Epoch 26/100
# 56/56 [==============================] - 0s 5ms/step - loss: 0.0198 - val_loss: 0.0179
# Epoch 27/100
# 56/56 [==============================] - 0s 5ms/step - loss: 0.0130 - val_loss: 0.0120
# Epoch 28/100
# 56/56 [==============================] - 0s 5ms/step - loss: 0.0107 - val_loss: 0.0101
# Epoch 29/100
# 56/56 [==============================] - 0s 5ms/step - loss: 0.0097 - val_loss: 0.0055
# Epoch 30/100
# 56/56 [==============================] - 0s 5ms/step - loss: 0.0090 - val_loss: 0.0043
# Epoch 31/100
# 56/56 [==============================] - 0s 5ms/step - loss: 0.0069 - val_loss: 0.0040
# Epoch 32/100
# 56/56 [==============================] - 0s 5ms/step - loss: 0.0073 - val_loss: 0.0032
# Epoch 33/100
# 56/56 [==============================] - 0s 6ms/step - loss: 0.0071 - val_loss: 0.0026
# Epoch 34/100
# 56/56 [==============================] - 0s 6ms/step - loss: 0.0057 - val_loss: 0.0025
# Epoch 35/100
# 56/56 [==============================] - 0s 5ms/step - loss: 0.0075 - val_loss: 0.0026
# Epoch 36/100
# 56/56 [==============================] - 0s 5ms/step - loss: 0.0070 - val_loss: 0.0025
# Epoch 37/100
# 56/56 [==============================] - 0s 6ms/step - loss: 0.0065 - val_loss: 0.0024
# Epoch 38/100
# 56/56 [==============================] - 0s 6ms/step - loss: 0.0062 - val_loss: 0.0025
# Epoch 39/100
# 56/56 [==============================] - 0s 6ms/step - loss: 0.0071 - val_loss: 0.0024
# Epoch 40/100
# 56/56 [==============================] - 0s 6ms/step - loss: 0.0066 - val_loss: 0.0025
# Epoch 41/100
# 56/56 [==============================] - 0s 6ms/step - loss: 0.0063 - val_loss: 0.0023
# Epoch 42/100
# 56/56 [==============================] - 0s 5ms/step - loss: 0.0053 - val_loss: 0.0042
# Epoch 43/100
# 56/56 [==============================] - 0s 6ms/step - loss: 0.0055 - val_loss: 0.0034
# Epoch 44/100
# 56/56 [==============================] - 0s 6ms/step - loss: 0.0052 - val_loss: 0.0030
# Epoch 45/100
# 56/56 [==============================] - 0s 5ms/step - loss: 0.0065 - val_loss: 0.0033
# Epoch 46/100
# 56/56 [==============================] - 0s 6ms/step - loss: 0.0053 - val_loss: 0.0029
# Epoch 47/100
# 56/56 [==============================] - 0s 5ms/step - loss: 0.0051 - val_loss: 0.0029
# Epoch 48/100
# 56/56 [==============================] - 0s 6ms/step - loss: 0.0052 - val_loss: 0.0027
# Epoch 49/100
# 56/56 [==============================] - 0s 5ms/step - loss: 0.0058 - val_loss: 0.0032
# Epoch 50/100
# 56/56 [==============================] - 0s 6ms/step - loss: 0.0046 - val_loss: 0.0029
# Epoch 51/100
# 56/56 [==============================] - 0s 6ms/step - loss: 0.0049 - val_loss: 0.0028
# Epoch 52/100
# 56/56 [==============================] - 0s 5ms/step - loss: 0.0048 - val_loss: 0.0029
# Epoch 53/100
# 56/56 [==============================] - 0s 6ms/step - loss: 0.0077 - val_loss: 0.0029
# Epoch 54/100
# 56/56 [==============================] - 0s 5ms/step - loss: 0.0052 - val_loss: 0.0030
# Epoch 55/100
# 56/56 [==============================] - 0s 6ms/step - loss: 0.0051 - val_loss: 0.0029
# Epoch 56/100
# 56/56 [==============================] - 0s 6ms/step - loss: 0.0050 - val_loss: 0.0031
# Epoch 57/100
# 56/56 [==============================] - 0s 5ms/step - loss: 0.0045 - val_loss: 0.0027
# Epoch 58/100
# 56/56 [==============================] - 0s 5ms/step - loss: 0.0047 - val_loss: 0.0030
# Epoch 59/100
# 56/56 [==============================] - 0s 5ms/step - loss: 0.0044 - val_loss: 0.0029
# Epoch 60/100
# 56/56 [==============================] - 0s 6ms/step - loss: 0.0049 - val_loss: 0.0029
# Epoch 61/100
# 56/56 [==============================] - 0s 5ms/step - loss: 0.0040 - val_loss: 0.0026
# Epoch 62/100
# 56/56 [==============================] - 0s 5ms/step - loss: 0.0043 - val_loss: 0.0033
# Epoch 63/100
# 56/56 [==============================] - 0s 5ms/step - loss: 0.0046 - val_loss: 0.0027
# Epoch 64/100
# 56/56 [==============================] - 0s 5ms/step - loss: 0.0042 - val_loss: 0.0028
# Epoch 65/100
# 56/56 [==============================] - 0s 5ms/step - loss: 0.0046 - val_loss: 0.0026
# Epoch 66/100
# 56/56 [==============================] - 0s 5ms/step - loss: 0.0053 - val_loss: 0.0037
# Epoch 67/100
# 56/56 [==============================] - 0s 5ms/step - loss: 0.0047 - val_loss: 0.0037
# Epoch 68/100
# 56/56 [==============================] - 0s 6ms/step - loss: 0.0044 - val_loss: 0.0027
# Epoch 69/100
# 56/56 [==============================] - 0s 5ms/step - loss: 0.0048 - val_loss: 0.0026
# Epoch 70/100
# 56/56 [==============================] - 0s 8ms/step - loss: 0.0037 - val_loss: 0.0024
# Epoch 71/100
# 56/56 [==============================] - 0s 8ms/step - loss: 0.0038 - val_loss: 0.0028
# Epoch 72/100
# 56/56 [==============================] - 1s 10ms/step - loss: 0.0043 - val_loss: 0.0024
# Epoch 73/100
# 56/56 [==============================] - 1s 10ms/step - loss: 0.0040 - val_loss: 0.0019
# Epoch 74/100
# 56/56 [==============================] - 0s 9ms/step - loss: 0.0033 - val_loss: 0.0016
# Epoch 75/100
# 56/56 [==============================] - 0s 7ms/step - loss: 0.0040 - val_loss: 0.0019
# Epoch 76/100
# 56/56 [==============================] - 0s 6ms/step - loss: 0.0037 - val_loss: 0.0018
# Epoch 77/100
# 56/56 [==============================] - 0s 6ms/step - loss: 0.0050 - val_loss: 0.0018
# Epoch 78/100
# 56/56 [==============================] - 0s 6ms/step - loss: 0.0038 - val_loss: 0.0021
# Epoch 79/100
# 56/56 [==============================] - 0s 6ms/step - loss: 0.0043 - val_loss: 0.0036
# Epoch 80/100
# 56/56 [==============================] - 0s 6ms/step - loss: 0.0042 - val_loss: 0.0019
# Epoch 81/100
# 56/56 [==============================] - 0s 6ms/step - loss: 0.0041 - val_loss: 0.0018
# Epoch 82/100
# 56/56 [==============================] - 0s 6ms/step - loss: 0.0037 - val_loss: 0.0024
# Epoch 83/100
# 56/56 [==============================] - 0s 8ms/step - loss: 0.0038 - val_loss: 0.0019
# Epoch 84/100
# 56/56 [==============================] - 0s 6ms/step - loss: 0.0033 - val_loss: 0.0018
# Epoch 85/100
# 56/56 [==============================] - 0s 6ms/step - loss: 0.0035 - val_loss: 0.0019
# Epoch 86/100
# 56/56 [==============================] - 0s 6ms/step - loss: 0.0029 - val_loss: 0.0018
# Epoch 87/100
# 56/56 [==============================] - 0s 6ms/step - loss: 0.0032 - val_loss: 0.0020
# Epoch 88/100
# 56/56 [==============================] - 0s 6ms/step - loss: 0.0033 - val_loss: 0.0019
# Epoch 89/100
# 56/56 [==============================] - 0s 6ms/step - loss: 0.0034 - val_loss: 0.0018
# Epoch 90/100
# 56/56 [==============================] - 0s 7ms/step - loss: 0.0031 - val_loss: 0.0020
# Epoch 91/100
# 56/56 [==============================] - 0s 6ms/step - loss: 0.0035 - val_loss: 0.0021
# Epoch 92/100
# 56/56 [==============================] - 0s 6ms/step - loss: 0.0036 - val_loss: 0.0020
# Epoch 93/100
# 56/56 [==============================] - 0s 6ms/step - loss: 0.0032 - val_loss: 0.0023
# Epoch 94/100
# 56/56 [==============================] - 0s 6ms/step - loss: 0.0032 - val_loss: 0.0018
# Epoch 95/100
# 56/56 [==============================] - 0s 6ms/step - loss: 0.0032 - val_loss: 0.0022
# Epoch 96/100
# 56/56 [==============================] - 0s 6ms/step - loss: 0.0030 - val_loss: 0.0020
# Epoch 97/100
# 56/56 [==============================] - 0s 7ms/step - loss: 0.0032 - val_loss: 0.0019
# Epoch 98/100
# 56/56 [==============================] - 0s 7ms/step - loss: 0.0031 - val_loss: 0.0019
# Epoch 99/100
# 56/56 [==============================] - 0s 6ms/step - loss: 0.0033 - val_loss: 0.0018
# Epoch 100/100
# 56/56 [==============================] - 0s 6ms/step - loss: 0.0028 - val_loss: 0.0021
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0032
# 0.0031768472399562597
